# %%
import os
import sys

current_dir = os.path.abspath(os.path.dirname("Tests_Bayesian_Optimization.ipynb"))
parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
sys.path.append(parent_dir)

from ppe.bayesian_optimization import Bayesian_Optimization
import numpy as np
import pymc as pm

# %% [markdown]
# ## Example 1: Simple Gaussian model
#
# We assume $ Y \sim \mathcal{N}(\theta, \sigma)$, with $\theta \sim \mathcal{N}(\mu_1, \sigma_1)$. Then, we have the hyperparameter vector $\pmb{\lambda} = [\mu_1, \sigma, \sigma_1]$. Also, for $ A = (a,b] $, we know that
#
# $$\mathbb{P}_{A|\pmb{\lambda}} = \Phi \Big((b - \mu_1)/\sqrt{\sigma^2 + \sigma_1^2} \Big) - \Phi \Big((a - \mu_1)/\sqrt{\sigma^2 + \sigma_1^2} \Big)$$

# %%
## Defining the pymc model

def gaussian_model(lam, n_samples):

    gaussian_model = pm.Model()

    with gaussian_model:

        theta = pm.Normal("theta", mu=lam["mu_1"], sigma=lam["sigma_1"])

        Y_obs = pm.Normal("Y_obs", mu=theta, sigma=lam["sigma"], observed=1.)

    with gaussian_model:

        idata = pm.sample_prior_predictive(samples = n_samples)

    return idata


## The partitions and expert probabilities for the target Y

partitions = [np.array([[-1000, -5], [-5, -1], [-1, 3], [3, 1000]])]

expert_probs = [np.array([0.1, 0.2, 0.6, 0.1])]



BO = Bayesian_Optimization(pymc_sampling_func=gaussian_model,
                              J = 1,
                              alpha=None,
                              target_type="continuous",
                              target_samples=1000)




param_names = ["mu_1", "sigma_1", "sigma", "alpha"] ## hyperparameter names. Alpha is optimized as well
param_types = ["range", "range", "range", "range"]
param_bounds = [[-10., 10.], [0.00001, 4.], [0.00001, 4.], [0.1, 20.]] ## bounds for each hyperparameter
param_expected_vals = [-1, 3, 1, None] ## expected values for the hyperparameters
param_weights = [1, 0.5, 0.5] ## level of confidence for each expected value



best_params = BO.optimize_hyperparams(param_names=param_names,
                                      param_types = param_types,
                                      param_bounds=param_bounds,
                                      param_expected_vals = param_expected_vals,
                                      param_weights = param_weights,
                                      partitions=partitions,
                                      expert_probs=expert_probs,
                                      n_trials=75)
# Out:
# [INFO 06-22 21:07:42] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter mu_1. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-22 21:07:42] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter sigma_1. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-22 21:07:42] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter sigma. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-22 21:07:42] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter alpha. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-22 21:07:42] ax.service.utils.instantiation: Created search space: SearchSpace(parameters=[RangeParameter(name='mu_1', parameter_type=FLOAT, range=[-10.0, 10.0]), RangeParameter(name='sigma_1', parameter_type=FLOAT, range=[1e-05, 4.0]), RangeParameter(name='sigma', parameter_type=FLOAT, range=[1e-05, 4.0]), RangeParameter(name='alpha', parameter_type=FLOAT, range=[0.1, 20.0])], parameter_constraints=[]).
# [INFO 06-22 21:07:42] ax.modelbridge.dispatch_utils: Using Models.BOTORCH_MODULAR since there is at least one ordered parameter and there are no unordered categorical parameters.
# [INFO 06-22 21:07:42] ax.modelbridge.dispatch_utils: Calculating the number of remaining initialization trials based on num_initialization_trials=None max_initialization_trials=None num_tunable_parameters=4 num_trials=None use_batch_trials=False
# [INFO 06-22 21:07:42] ax.modelbridge.dispatch_utils: calculated num_initialization_trials=8
# [INFO 06-22 21:07:42] ax.modelbridge.dispatch_utils: num_completed_initialization_trials=0 num_remaining_initialization_trials=8
# [INFO 06-22 21:07:42] ax.modelbridge.dispatch_utils: `verbose`, `disable_progbar`, and `jit_compile` are not yet supported when using `choose_generation_strategy` with ModularBoTorchModel, dropping these arguments.
# [INFO 06-22 21:07:42] ax.modelbridge.dispatch_utils: Using Bayesian Optimization generation strategy: GenerationStrategy(name='Sobol+BoTorch', steps=[Sobol for 8 trials, BoTorch for subsequent trials]). Iterations after 8 will take longer to generate due to model-fitting.
# [INFO 06-22 21:07:42] ax.service.managed_loop: Started full optimization with 75 steps.
# [INFO 06-22 21:07:42] ax.service.managed_loop: Running optimization trial 1...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:42] ax.service.managed_loop: Running optimization trial 2...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:43] ax.service.managed_loop: Running optimization trial 3...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:43] ax.service.managed_loop: Running optimization trial 4...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:43] ax.service.managed_loop: Running optimization trial 5...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:43] ax.service.managed_loop: Running optimization trial 6...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:43] ax.service.managed_loop: Running optimization trial 7...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:43] ax.service.managed_loop: Running optimization trial 8...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:43] ax.service.managed_loop: Running optimization trial 9...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:43] ax.service.managed_loop: Running optimization trial 10...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:43] ax.service.managed_loop: Running optimization trial 11...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:44] ax.service.managed_loop: Running optimization trial 12...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:44] ax.service.managed_loop: Running optimization trial 13...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:44] ax.service.managed_loop: Running optimization trial 14...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:45] ax.service.managed_loop: Running optimization trial 15...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:45] ax.service.managed_loop: Running optimization trial 16...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:46] ax.service.managed_loop: Running optimization trial 17...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:46] ax.service.managed_loop: Running optimization trial 18...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:47] ax.service.managed_loop: Running optimization trial 19...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:47] ax.service.managed_loop: Running optimization trial 20...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:48] ax.service.managed_loop: Running optimization trial 21...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:49] ax.service.managed_loop: Running optimization trial 22...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:49] ax.service.managed_loop: Running optimization trial 23...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:50] ax.service.managed_loop: Running optimization trial 24...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:50] ax.service.managed_loop: Running optimization trial 25...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:51] ax.service.managed_loop: Running optimization trial 26...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:52] ax.service.managed_loop: Running optimization trial 27...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:52] ax.service.managed_loop: Running optimization trial 28...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:53] ax.service.managed_loop: Running optimization trial 29...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:54] ax.service.managed_loop: Running optimization trial 30...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:54] ax.service.managed_loop: Running optimization trial 31...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:55] ax.service.managed_loop: Running optimization trial 32...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:56] ax.service.managed_loop: Running optimization trial 33...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:57] ax.service.managed_loop: Running optimization trial 34...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:58] ax.service.managed_loop: Running optimization trial 35...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:58] ax.service.managed_loop: Running optimization trial 36...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:07:59] ax.service.managed_loop: Running optimization trial 37...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:00] ax.service.managed_loop: Running optimization trial 38...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:02] ax.service.managed_loop: Running optimization trial 39...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:02] ax.service.managed_loop: Running optimization trial 40...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:03] ax.service.managed_loop: Running optimization trial 41...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:05] ax.service.managed_loop: Running optimization trial 42...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:06] ax.service.managed_loop: Running optimization trial 43...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:07] ax.service.managed_loop: Running optimization trial 44...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:08] ax.service.managed_loop: Running optimization trial 45...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:09] ax.service.managed_loop: Running optimization trial 46...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:10] ax.service.managed_loop: Running optimization trial 47...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:10] ax.service.managed_loop: Running optimization trial 48...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:11] ax.service.managed_loop: Running optimization trial 49...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:11] ax.service.managed_loop: Running optimization trial 50...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:12] ax.service.managed_loop: Running optimization trial 51...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:13] ax.service.managed_loop: Running optimization trial 52...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:13] ax.service.managed_loop: Running optimization trial 53...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:13] ax.service.managed_loop: Running optimization trial 54...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:14] ax.service.managed_loop: Running optimization trial 55...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:14] ax.service.managed_loop: Running optimization trial 56...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:15] ax.service.managed_loop: Running optimization trial 57...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:15] ax.service.managed_loop: Running optimization trial 58...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:16] ax.service.managed_loop: Running optimization trial 59...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:17] ax.service.managed_loop: Running optimization trial 60...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:18] ax.service.managed_loop: Running optimization trial 61...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:18] ax.service.managed_loop: Running optimization trial 62...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:20] ax.service.managed_loop: Running optimization trial 63...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:21] ax.service.managed_loop: Running optimization trial 64...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:22] ax.service.managed_loop: Running optimization trial 65...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:22] ax.service.managed_loop: Running optimization trial 66...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:23] ax.service.managed_loop: Running optimization trial 67...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:24] ax.service.managed_loop: Running optimization trial 68...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:25] ax.service.managed_loop: Running optimization trial 69...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:26] ax.service.managed_loop: Running optimization trial 70...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:28] ax.service.managed_loop: Running optimization trial 71...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:29] ax.service.managed_loop: Running optimization trial 72...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:30] ax.service.managed_loop: Running optimization trial 73...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:31] ax.service.managed_loop: Running optimization trial 74...
# Sampling: [Y_obs, theta]
# [INFO 06-22 21:08:32] ax.service.managed_loop: Running optimization trial 75...
# Sampling: [Y_obs, theta]

# %%
best_params
# Out:
# {'mu_1': -0.3554812403270784,
#  'sigma_1': 1.6753267358736132,
#  'sigma': 2.6658464960514476,
#  'alpha': 15.339261251889845}

# %%
BO.eval_function(best_params, partitions, expert_probs) ##alpha
# Out:
# Sampling: [Y_obs, theta]
# Array(14.29274, dtype=float32)

# %%
BO.get_model_probs(best_params, partitions)
# Out:
# Sampling: [Y_obs, theta]
# [array([0.085, 0.331, 0.443, 0.141])]

# %%
def classification_model(lam, n_samples):

    RANDOM_SEED = 8927

    covs = np.array([[1.3, 0.7, 0.5, -0.7, -0.5],
                     [1, 0.5, 0.4, -0.8, 0],
                     [0.3, 0.7, 2, -2, 0.2]])

    classification_model = pm.Model()

    with classification_model:

        theta_1 = pm.Normal("theta_1", mu=lam["mu_1"], sigma=lam["sigma_1"])
        theta_2 = pm.Normal("theta_2", mu=lam["mu_2"], sigma=lam["sigma_2"])
        theta_3 = pm.Normal("theta_3", mu=lam["mu_3"], sigma=lam["sigma_3"])
        theta_4 = pm.Normal("theta_4", mu=lam["mu_4"], sigma=lam["sigma_4"])
        theta_5 = pm.Normal("theta_5", mu=lam["mu_5"], sigma=lam["sigma_5"])

        theta = pm.math.stack([theta_1, theta_2, theta_3, theta_4, theta_5])

        p = pm.math.dot(covs, theta)

        p = 0.5 + 0.5 * pm.math.erf(p / pm.math.sqrt(2))

        Y_obs = pm.Bernoulli("Y_obs", p = p, observed=np.ones(covs.shape[0]))

    with classification_model:
        idata = pm.sample_prior_predictive(random_seed=RANDOM_SEED, samples = n_samples)

    return idata



BO = Bayesian_Optimization(pymc_sampling_func=classification_model,
                              J = 3,
                              alpha=None,
                              target_type="discrete",
                              target_samples=1000)


param_names = ["mu_1", "sigma_1",
               "mu_2", "sigma_2",
               "mu_3", "sigma_3",
               "mu_4", "sigma_4",
               "mu_5", "sigma_5",
               "alpha"]

param_types = ["range"]*len(param_names)


partitions = np.array([0, 1]) ## binary partition

expert_probs = [np.array([0.65, 0.35]),
                np.array([0.3, 0.7]),
                np.array([0.2, 0.8])]



param_bounds = [[-6., 6.], [0.00001, 2.],
                [-6., 6.], [0.00001, 2.],
                [-6., 6.], [0.00001, 2.],
                [-6., 6.], [0.00001, 2.],
                [-6., 6.], [0.00001, 2.],
                [0.1, 200.]]

param_expected_vals = [1, 1,
                       -0.2, 1,
                       -1, 1,
                       1, 1,
                       -0.5, 1,
                       None]



param_weights = [1, 0.5,
                 1, 0.5,
                 1, 0.5,
                 1, 0.5,
                 1, 0.5]


best_params = BO.optimize_hyperparams(param_names=param_names,
                                      param_types=param_types,
                                      param_bounds=param_bounds,
                                      param_expected_vals = param_expected_vals,
                                      param_weights = param_weights,
                                      partitions=partitions,
                                      expert_probs=expert_probs,
                                      n_trials=100)
# Out:
# [INFO 06-18 17:12:23] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter mu_1. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-18 17:12:23] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter sigma_1. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-18 17:12:23] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter mu_2. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-18 17:12:23] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter sigma_2. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-18 17:12:23] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter mu_3. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-18 17:12:23] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter sigma_3. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-18 17:12:23] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter mu_4. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-18 17:12:23] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter sigma_4. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-18 17:12:23] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter mu_5. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-18 17:12:23] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter sigma_5. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-18 17:12:23] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter alpha. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-18 17:12:23] ax.service.utils.instantiation: Created search space: SearchSpace(parameters=[RangeParameter(name='mu_1', parameter_type=FLOAT, range=[-6.0, 6.0]), RangeParameter(name='sigma_1', parameter_type=FLOAT, range=[1e-05, 2.0]), RangeParameter(name='mu_2', parameter_type=FLOAT, range=[-6.0, 6.0]), RangeParameter(name='sigma_2', parameter_type=FLOAT, range=[1e-05, 2.0]), RangeParameter(name='mu_3', parameter_type=FLOAT, range=[-6.0, 6.0]), RangeParameter(name='sigma_3', parameter_type=FLOAT, range=[1e-05, 2.0]), RangeParameter(name='mu_4', parameter_type=FLOAT, range=[-6.0, 6.0]), RangeParameter(name='sigma_4', parameter_type=FLOAT, range=[1e-05, 2.0]), RangeParameter(name='mu_5', parameter_type=FLOAT, range=[-6.0, 6.0]), RangeParameter(name='sigma_5', parameter_type=FLOAT, range=[1e-05, 2.0]), RangeParameter(name='alpha', parameter_type=FLOAT, range=[0.1, 200.0])], parameter_constraints=[]).
# [INFO 06-18 17:12:23] ax.modelbridge.dispatch_utils: Using Models.BOTORCH_MODULAR since there is at least one ordered parameter and there are no unordered categorical parameters.
# [INFO 06-18 17:12:23] ax.modelbridge.dispatch_utils: Calculating the number of remaining initialization trials based on num_initialization_trials=None max_initialization_trials=None num_tunable_parameters=11 num_trials=None use_batch_trials=False
# [INFO 06-18 17:12:23] ax.modelbridge.dispatch_utils: calculated num_initialization_trials=22
# [INFO 06-18 17:12:23] ax.modelbridge.dispatch_utils: num_completed_initialization_trials=0 num_remaining_initialization_trials=22
# [INFO 06-18 17:12:23] ax.modelbridge.dispatch_utils: `verbose`, `disable_progbar`, and `jit_compile` are not yet supported when using `choose_generation_strategy` with ModularBoTorchModel, dropping these arguments.
# [INFO 06-18 17:12:23] ax.modelbridge.dispatch_utils: Using Bayesian Optimization generation strategy: GenerationStrategy(name='Sobol+BoTorch', steps=[Sobol for 22 trials, BoTorch for subsequent trials]). Iterations after 22 will take longer to generate due to model-fitting.
# [INFO 06-18 17:12:23] ax.service.managed_loop: Started full optimization with 100 steps.
# [INFO 06-18 17:12:23] ax.service.managed_loop: Running optimization trial 1...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:24] ax.service.managed_loop: Running optimization trial 2...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:24] ax.service.managed_loop: Running optimization trial 3...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:24] ax.service.managed_loop: Running optimization trial 4...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:24] ax.service.managed_loop: Running optimization trial 5...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:25] ax.service.managed_loop: Running optimization trial 6...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:25] ax.service.managed_loop: Running optimization trial 7...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:25] ax.service.managed_loop: Running optimization trial 8...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:25] ax.service.managed_loop: Running optimization trial 9...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:25] ax.service.managed_loop: Running optimization trial 10...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:25] ax.service.managed_loop: Running optimization trial 11...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:25] ax.service.managed_loop: Running optimization trial 12...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:25] ax.service.managed_loop: Running optimization trial 13...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:25] ax.service.managed_loop: Running optimization trial 14...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:25] ax.service.managed_loop: Running optimization trial 15...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:26] ax.service.managed_loop: Running optimization trial 16...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:26] ax.service.managed_loop: Running optimization trial 17...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:26] ax.service.managed_loop: Running optimization trial 18...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:26] ax.service.managed_loop: Running optimization trial 19...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:26] ax.service.managed_loop: Running optimization trial 20...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:26] ax.service.managed_loop: Running optimization trial 21...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:26] ax.service.managed_loop: Running optimization trial 22...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:26] ax.service.managed_loop: Running optimization trial 23...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:27] ax.service.managed_loop: Running optimization trial 24...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:27] ax.service.managed_loop: Running optimization trial 25...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:28] ax.service.managed_loop: Running optimization trial 26...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:29] ax.service.managed_loop: Running optimization trial 27...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:29] ax.service.managed_loop: Running optimization trial 28...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:30] ax.service.managed_loop: Running optimization trial 29...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:31] ax.service.managed_loop: Running optimization trial 30...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:32] ax.service.managed_loop: Running optimization trial 31...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:33] ax.service.managed_loop: Running optimization trial 32...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:34] ax.service.managed_loop: Running optimization trial 33...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:35] ax.service.managed_loop: Running optimization trial 34...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:35] ax.service.managed_loop: Running optimization trial 35...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:36] ax.service.managed_loop: Running optimization trial 36...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:37] ax.service.managed_loop: Running optimization trial 37...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:37] ax.service.managed_loop: Running optimization trial 38...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:38] ax.service.managed_loop: Running optimization trial 39...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:38] ax.service.managed_loop: Running optimization trial 40...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:39] ax.service.managed_loop: Running optimization trial 41...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:40] ax.service.managed_loop: Running optimization trial 42...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:41] ax.service.managed_loop: Running optimization trial 43...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:42] ax.service.managed_loop: Running optimization trial 44...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:43] ax.service.managed_loop: Running optimization trial 45...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:43] ax.service.managed_loop: Running optimization trial 46...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:44] ax.service.managed_loop: Running optimization trial 47...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:45] ax.service.managed_loop: Running optimization trial 48...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:46] ax.service.managed_loop: Running optimization trial 49...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:47] ax.service.managed_loop: Running optimization trial 50...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:49] ax.service.managed_loop: Running optimization trial 51...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:50] ax.service.managed_loop: Running optimization trial 52...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:50] ax.service.managed_loop: Running optimization trial 53...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:51] ax.service.managed_loop: Running optimization trial 54...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:52] ax.service.managed_loop: Running optimization trial 55...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:53] ax.service.managed_loop: Running optimization trial 56...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:54] ax.service.managed_loop: Running optimization trial 57...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:55] ax.service.managed_loop: Running optimization trial 58...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:56] ax.service.managed_loop: Running optimization trial 59...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:57] ax.service.managed_loop: Running optimization trial 60...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:58] ax.service.managed_loop: Running optimization trial 61...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:12:59] ax.service.managed_loop: Running optimization trial 62...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:00] ax.service.managed_loop: Running optimization trial 63...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:01] ax.service.managed_loop: Running optimization trial 64...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:02] ax.service.managed_loop: Running optimization trial 65...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:03] ax.service.managed_loop: Running optimization trial 66...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:05] ax.service.managed_loop: Running optimization trial 67...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:07] ax.service.managed_loop: Running optimization trial 68...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:08] ax.service.managed_loop: Running optimization trial 69...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:09] ax.service.managed_loop: Running optimization trial 70...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:11] ax.service.managed_loop: Running optimization trial 71...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:12] ax.service.managed_loop: Running optimization trial 72...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:14] ax.service.managed_loop: Running optimization trial 73...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:15] ax.service.managed_loop: Running optimization trial 74...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:16] ax.service.managed_loop: Running optimization trial 75...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:18] ax.service.managed_loop: Running optimization trial 76...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:19] ax.service.managed_loop: Running optimization trial 77...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:21] ax.service.managed_loop: Running optimization trial 78...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:23] ax.service.managed_loop: Running optimization trial 79...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:25] ax.service.managed_loop: Running optimization trial 80...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:26] ax.service.managed_loop: Running optimization trial 81...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:28] ax.service.managed_loop: Running optimization trial 82...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:29] ax.service.managed_loop: Running optimization trial 83...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:31] ax.service.managed_loop: Running optimization trial 84...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:32] ax.service.managed_loop: Running optimization trial 85...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:33] ax.service.managed_loop: Running optimization trial 86...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:35] ax.service.managed_loop: Running optimization trial 87...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:36] ax.service.managed_loop: Running optimization trial 88...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:38] ax.service.managed_loop: Running optimization trial 89...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:39] ax.service.managed_loop: Running optimization trial 90...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:41] ax.service.managed_loop: Running optimization trial 91...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:43] ax.service.managed_loop: Running optimization trial 92...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:45] ax.service.managed_loop: Running optimization trial 93...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:47] ax.service.managed_loop: Running optimization trial 94...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:49] ax.service.managed_loop: Running optimization trial 95...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:50] ax.service.managed_loop: Running optimization trial 96...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:53] ax.service.managed_loop: Running optimization trial 97...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:55] ax.service.managed_loop: Running optimization trial 98...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:13:58] ax.service.managed_loop: Running optimization trial 99...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [INFO 06-18 17:14:00] ax.service.managed_loop: Running optimization trial 100...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]

# %%
best_params
# Out:
# {'mu_1': 0.9718008834248018,
#  'sigma_1': 0.6667984120521077,
#  'mu_2': 0.910968254444378,
#  'sigma_2': 1.756528288365451,
#  'mu_3': 3.1383923733929784,
#  'sigma_3': 0.8880837841992402,
#  'mu_4': 2.762692578451336,
#  'sigma_4': 0.7906300403350193,
#  'mu_5': 3.881649176968473,
#  'sigma_5': 0.9061322879255975,
#  'alpha': 10.428035130034436}

# %%
BO.eval_function(best_params, partitions, expert_probs)
# Out:
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# Array(42.79135, dtype=float32)

# %%
BO.get_model_probs(best_params, partitions)
# Out:
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5]
# [array([0.588, 0.412]), array([0.409, 0.591]), array([0.205, 0.795])]

# %%
partitions = np.array([0, 1])  ## We have a classification task


## input for the expert probabilities (J=6 covariate sets in total)

expert_probs = [np.array([0.8854, 0.1146]),
                np.array([0.7857, 0.2143]),
                np.array([0.2237, 0.7763]),
                np.array([0.9023, 0.0977]),
                np.array([0.8167, 0.1833]),
                np.array([0.7857, 0.2143])]


## the logistic regression model

def trauma_center_model(lam, n_samples):


    ## values for the covariates. The first row (column when transposed) is for the intercept

    covs = np.array([[1,1,1,1,1,1],
                     [25,25,41,41,33,33],
                     [7.84, 3.34, 3.34, 7.84, 5.74, 5.74],
                     [60, 10, 60, 10, 35, 35],
                     [0,0,1,1,0,1],
                     [0,0,60,10,0,35]]).T

    trauma_center_model = pm.Model()

    with trauma_center_model:

        theta_1 = pm.Normal("theta_1", mu=lam["mu_1"], sigma=lam["sigma_1"])
        theta_2 = pm.Normal("theta_2", mu=lam["mu_2"], sigma=lam["sigma_2"])
        theta_3 = pm.Normal("theta_3", mu=lam["mu_3"], sigma=lam["sigma_3"])
        theta_4 = pm.Normal("theta_4", mu=lam["mu_4"], sigma=lam["sigma_4"])
        theta_5 = pm.Normal("theta_5", mu=lam["mu_5"], sigma=lam["sigma_5"])
        theta_6 = pm.Normal("theta_6", mu=lam["mu_6"], sigma=lam["sigma_6"])

        theta = pm.math.stack([theta_1, theta_2, theta_3, theta_4, theta_5, theta_6])

        xTtheta = pm.math.dot(covs, theta)

        p = pm.math.exp(xTtheta) / (1 + pm.math.exp(xTtheta))

        Y_obs = pm.Bernoulli("Y_obs", p = p, observed=np.ones(covs.shape[0]))

    with trauma_center_model:
        idata = pm.sample_prior_predictive(samples=n_samples)

    return idata



BO = Bayesian_Optimization(pymc_sampling_func=trauma_center_model,
                              J = 6,
                              alpha=None,
                              target_type="discrete",
                              target_samples=1500)





param_names = ["mu_1", "sigma_1",
               "mu_2", "sigma_2",
               "mu_3", "sigma_3",
               "mu_4", "sigma_4",
               "mu_5", "sigma_5",
               "mu_6", "sigma_6",
               "alpha"]


param_types = ["range", "range",
               "range", "range",
               "range", "range",
               "range", "range",
               "range", "range",
               "range", "range",
               "range"]

'''   
param_types = ["range", "choice",
               "range", "choice",
               "range", "choice",
               "range", "choice",
               "range", "choice",
               "range", "choice",
               "range"]'''


## the bounds for each hyperparameter

param_bounds = [[-4., 4.], [0.00001, 3.],
                [-4., 4.], [0.00001, 3.],
                [-4., 4.], [0.00001, 3.],
                [-4., 4.], [0.00001, 3.],
                [-4., 4.], [0.00001, 3.],
                [-4., 4.], [0.00001, 3.],
                [0.1, 100.]]

'''
param_bounds = [[-4., 4.], [float(10**i) for i in range(-5,1)],
                [-4., 4.], [float(10**i) for i in range(-5,1)],
                [-4., 4.], [float(10**i) for i in range(-5,1)],
                [-4., 4.], [float(10**i) for i in range(-5,1)],
                [-4., 4.], [float(10**i) for i in range(-5,1)],
                [-4., 4.], [float(10**i) for i in range(-5,1)],
                [0.1, 100.]]
'''

## expected values (taken from the thesis, these correspond to the posterior means and standard deviations from the original study)

param_expected_vals = [-1.8, 1.1,
                       0.07, 0.02,
                       -0.6, 0.14,
                       0.05, 0.01,
                       -1.1, 1.06,
                       -0.02, 0.03,
                       None]



'''
param_expected_vals = [-1.8, None,
                       0.07, None,
                       -0.6, None,
                       0.05, None,
                       -1.1, None,
                       -0.02, None,
                       None]
'''
## Full confidence for each expected hyperparameter value (all weights=1)

param_weights = np.ones(len(param_bounds))



best_params = BO.optimize_hyperparams(param_names=param_names,
                                      param_types=param_types,
                                      param_bounds=param_bounds,
                                      param_expected_vals = param_expected_vals,
                                      param_weights = param_weights,
                                      partitions=partitions,
                                      expert_probs=expert_probs,
                                      n_trials=250)
# Out:
# [INFO 06-23 11:50:01] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter mu_1. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-23 11:50:01] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter sigma_1. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-23 11:50:01] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter mu_2. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-23 11:50:01] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter sigma_2. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-23 11:50:01] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter mu_3. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-23 11:50:01] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter sigma_3. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-23 11:50:01] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter mu_4. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-23 11:50:01] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter sigma_4. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-23 11:50:01] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter mu_5. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-23 11:50:01] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter sigma_5. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-23 11:50:01] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter mu_6. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-23 11:50:01] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter sigma_6. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-23 11:50:01] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter alpha. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-23 11:50:01] ax.service.utils.instantiation: Created search space: SearchSpace(parameters=[RangeParameter(name='mu_1', parameter_type=FLOAT, range=[-4.0, 4.0]), RangeParameter(name='sigma_1', parameter_type=FLOAT, range=[1e-05, 3.0]), RangeParameter(name='mu_2', parameter_type=FLOAT, range=[-4.0, 4.0]), RangeParameter(name='sigma_2', parameter_type=FLOAT, range=[1e-05, 3.0]), RangeParameter(name='mu_3', parameter_type=FLOAT, range=[-4.0, 4.0]), RangeParameter(name='sigma_3', parameter_type=FLOAT, range=[1e-05, 3.0]), RangeParameter(name='mu_4', parameter_type=FLOAT, range=[-4.0, 4.0]), RangeParameter(name='sigma_4', parameter_type=FLOAT, range=[1e-05, 3.0]), RangeParameter(name='mu_5', parameter_type=FLOAT, range=[-4.0, 4.0]), RangeParameter(name='sigma_5', parameter_type=FLOAT, range=[1e-05, 3.0]), RangeParameter(name='mu_6', parameter_type=FLOAT, range=[-4.0, 4.0]), RangeParameter(name='sigma_6', parameter_type=FLOAT, range=[1e-05, 3.0]), RangeParameter(name='alpha', parameter_type=FLOAT, range=[0.1, 100.0])], parameter_constraints=[]).
# [INFO 06-23 11:50:01] ax.modelbridge.dispatch_utils: Using Models.BOTORCH_MODULAR since there is at least one ordered parameter and there are no unordered categorical parameters.
# [INFO 06-23 11:50:01] ax.modelbridge.dispatch_utils: Calculating the number of remaining initialization trials based on num_initialization_trials=None max_initialization_trials=None num_tunable_parameters=13 num_trials=None use_batch_trials=False
# [INFO 06-23 11:50:01] ax.modelbridge.dispatch_utils: calculated num_initialization_trials=26
# [INFO 06-23 11:50:01] ax.modelbridge.dispatch_utils: num_completed_initialization_trials=0 num_remaining_initialization_trials=26
# [INFO 06-23 11:50:01] ax.modelbridge.dispatch_utils: `verbose`, `disable_progbar`, and `jit_compile` are not yet supported when using `choose_generation_strategy` with ModularBoTorchModel, dropping these arguments.
# [INFO 06-23 11:50:01] ax.modelbridge.dispatch_utils: Using Bayesian Optimization generation strategy: GenerationStrategy(name='Sobol+BoTorch', steps=[Sobol for 26 trials, BoTorch for subsequent trials]). Iterations after 26 will take longer to generate due to model-fitting.
# [INFO 06-23 11:50:01] ax.service.managed_loop: Started full optimization with 250 steps.
# [INFO 06-23 11:50:01] ax.service.managed_loop: Running optimization trial 1...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:01] ax.service.managed_loop: Running optimization trial 2...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:02] ax.service.managed_loop: Running optimization trial 3...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:02] ax.service.managed_loop: Running optimization trial 4...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:02] ax.service.managed_loop: Running optimization trial 5...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:02] ax.service.managed_loop: Running optimization trial 6...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:02] ax.service.managed_loop: Running optimization trial 7...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:02] ax.service.managed_loop: Running optimization trial 8...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:02] ax.service.managed_loop: Running optimization trial 9...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:03] ax.service.managed_loop: Running optimization trial 10...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:03] ax.service.managed_loop: Running optimization trial 11...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:03] ax.service.managed_loop: Running optimization trial 12...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:03] ax.service.managed_loop: Running optimization trial 13...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:03] ax.service.managed_loop: Running optimization trial 14...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:03] ax.service.managed_loop: Running optimization trial 15...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:03] ax.service.managed_loop: Running optimization trial 16...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:03] ax.service.managed_loop: Running optimization trial 17...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:04] ax.service.managed_loop: Running optimization trial 18...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:04] ax.service.managed_loop: Running optimization trial 19...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:04] ax.service.managed_loop: Running optimization trial 20...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:04] ax.service.managed_loop: Running optimization trial 21...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:04] ax.service.managed_loop: Running optimization trial 22...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:04] ax.service.managed_loop: Running optimization trial 23...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:04] ax.service.managed_loop: Running optimization trial 24...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:04] ax.service.managed_loop: Running optimization trial 25...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:05] ax.service.managed_loop: Running optimization trial 26...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:05] ax.service.managed_loop: Running optimization trial 27...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:05] ax.service.managed_loop: Running optimization trial 28...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:06] ax.service.managed_loop: Running optimization trial 29...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:06] ax.service.managed_loop: Running optimization trial 30...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:07] ax.service.managed_loop: Running optimization trial 31...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:08] ax.service.managed_loop: Running optimization trial 32...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:09] ax.service.managed_loop: Running optimization trial 33...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:10] ax.service.managed_loop: Running optimization trial 34...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:11] ax.service.managed_loop: Running optimization trial 35...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:12] ax.service.managed_loop: Running optimization trial 36...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:13] ax.service.managed_loop: Running optimization trial 37...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:14] ax.service.managed_loop: Running optimization trial 38...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:16] ax.service.managed_loop: Running optimization trial 39...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:17] ax.service.managed_loop: Running optimization trial 40...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:18] ax.service.managed_loop: Running optimization trial 41...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:19] ax.service.managed_loop: Running optimization trial 42...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:19] ax.service.managed_loop: Running optimization trial 43...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:20] ax.service.managed_loop: Running optimization trial 44...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:21] ax.service.managed_loop: Running optimization trial 45...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:22] ax.service.managed_loop: Running optimization trial 46...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:23] ax.service.managed_loop: Running optimization trial 47...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:23] ax.service.managed_loop: Running optimization trial 48...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:24] ax.service.managed_loop: Running optimization trial 49...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:25] ax.service.managed_loop: Running optimization trial 50...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:26] ax.service.managed_loop: Running optimization trial 51...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:27] ax.service.managed_loop: Running optimization trial 52...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:28] ax.service.managed_loop: Running optimization trial 53...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:29] ax.service.managed_loop: Running optimization trial 54...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:30] ax.service.managed_loop: Running optimization trial 55...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:31] ax.service.managed_loop: Running optimization trial 56...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:31] ax.service.managed_loop: Running optimization trial 57...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:33] ax.service.managed_loop: Running optimization trial 58...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:34] ax.service.managed_loop: Running optimization trial 59...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:35] ax.service.managed_loop: Running optimization trial 60...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:37] ax.service.managed_loop: Running optimization trial 61...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:39] ax.service.managed_loop: Running optimization trial 62...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:41] ax.service.managed_loop: Running optimization trial 63...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:43] ax.service.managed_loop: Running optimization trial 64...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:45] ax.service.managed_loop: Running optimization trial 65...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:47] ax.service.managed_loop: Running optimization trial 66...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:48] ax.service.managed_loop: Running optimization trial 67...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:50] ax.service.managed_loop: Running optimization trial 68...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:52] ax.service.managed_loop: Running optimization trial 69...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:53] ax.service.managed_loop: Running optimization trial 70...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:55] ax.service.managed_loop: Running optimization trial 71...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:50:58] ax.service.managed_loop: Running optimization trial 72...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:51:00] ax.service.managed_loop: Running optimization trial 73...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:51:02] ax.service.managed_loop: Running optimization trial 74...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:51:03] ax.service.managed_loop: Running optimization trial 75...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:51:06] ax.service.managed_loop: Running optimization trial 76...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:51:08] ax.service.managed_loop: Running optimization trial 77...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:51:09] ax.service.managed_loop: Running optimization trial 78...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:51:10] ax.service.managed_loop: Running optimization trial 79...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:51:12] ax.service.managed_loop: Running optimization trial 80...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:51:14] ax.service.managed_loop: Running optimization trial 81...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:51:15] ax.service.managed_loop: Running optimization trial 82...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:51:18] ax.service.managed_loop: Running optimization trial 83...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:51:19] ax.service.managed_loop: Running optimization trial 84...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:51:22] ax.service.managed_loop: Running optimization trial 85...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:51:27] ax.service.managed_loop: Running optimization trial 86...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:51:30] ax.service.managed_loop: Running optimization trial 87...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:51:34] ax.service.managed_loop: Running optimization trial 88...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:51:36] ax.service.managed_loop: Running optimization trial 89...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:51:40] ax.service.managed_loop: Running optimization trial 90...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:51:45] ax.service.managed_loop: Running optimization trial 91...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:51:50] ax.service.managed_loop: Running optimization trial 92...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:51:54] ax.service.managed_loop: Running optimization trial 93...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:51:56] ax.service.managed_loop: Running optimization trial 94...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:52:01] ax.service.managed_loop: Running optimization trial 95...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:52:04] ax.service.managed_loop: Running optimization trial 96...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:52:08] ax.service.managed_loop: Running optimization trial 97...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:52:11] ax.service.managed_loop: Running optimization trial 98...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:52:14] ax.service.managed_loop: Running optimization trial 99...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:52:17] ax.service.managed_loop: Running optimization trial 100...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:52:20] ax.service.managed_loop: Running optimization trial 101...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:52:24] ax.service.managed_loop: Running optimization trial 102...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:52:30] ax.service.managed_loop: Running optimization trial 103...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:52:34] ax.service.managed_loop: Running optimization trial 104...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:52:38] ax.service.managed_loop: Running optimization trial 105...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:52:43] ax.service.managed_loop: Running optimization trial 106...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:52:48] ax.service.managed_loop: Running optimization trial 107...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:52:52] ax.service.managed_loop: Running optimization trial 108...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:52:57] ax.service.managed_loop: Running optimization trial 109...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:53:02] ax.service.managed_loop: Running optimization trial 110...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:53:08] ax.service.managed_loop: Running optimization trial 111...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:53:13] ax.service.managed_loop: Running optimization trial 112...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:53:17] ax.service.managed_loop: Running optimization trial 113...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:53:21] ax.service.managed_loop: Running optimization trial 114...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:53:27] ax.service.managed_loop: Running optimization trial 115...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:53:33] ax.service.managed_loop: Running optimization trial 116...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:53:41] ax.service.managed_loop: Running optimization trial 117...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:53:48] ax.service.managed_loop: Running optimization trial 118...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:53:54] ax.service.managed_loop: Running optimization trial 119...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:54:00] ax.service.managed_loop: Running optimization trial 120...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:54:05] ax.service.managed_loop: Running optimization trial 121...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:54:10] ax.service.managed_loop: Running optimization trial 122...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:54:16] ax.service.managed_loop: Running optimization trial 123...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:54:23] ax.service.managed_loop: Running optimization trial 124...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:54:27] ax.service.managed_loop: Running optimization trial 125...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:54:32] ax.service.managed_loop: Running optimization trial 126...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:54:39] ax.service.managed_loop: Running optimization trial 127...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:54:46] ax.service.managed_loop: Running optimization trial 128...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:54:55] ax.service.managed_loop: Running optimization trial 129...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:55:03] ax.service.managed_loop: Running optimization trial 130...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:55:14] ax.service.managed_loop: Running optimization trial 131...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:55:20] ax.service.managed_loop: Running optimization trial 132...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:55:28] ax.service.managed_loop: Running optimization trial 133...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:55:34] ax.service.managed_loop: Running optimization trial 134...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:55:44] ax.service.managed_loop: Running optimization trial 135...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:55:50] ax.service.managed_loop: Running optimization trial 136...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:55:58] ax.service.managed_loop: Running optimization trial 137...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:56:03] ax.service.managed_loop: Running optimization trial 138...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:56:13] ax.service.managed_loop: Running optimization trial 139...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:56:19] ax.service.managed_loop: Running optimization trial 140...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:56:25] ax.service.managed_loop: Running optimization trial 141...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:56:35] ax.service.managed_loop: Running optimization trial 142...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:56:49] ax.service.managed_loop: Running optimization trial 143...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:56:58] ax.service.managed_loop: Running optimization trial 144...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:57:09] ax.service.managed_loop: Running optimization trial 145...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:57:20] ax.service.managed_loop: Running optimization trial 146...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:57:27] ax.service.managed_loop: Running optimization trial 147...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:57:33] ax.service.managed_loop: Running optimization trial 148...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:57:36] ax.service.managed_loop: Running optimization trial 149...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:57:41] ax.service.managed_loop: Running optimization trial 150...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:57:49] ax.service.managed_loop: Running optimization trial 151...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:57:54] ax.service.managed_loop: Running optimization trial 152...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:58:03] ax.service.managed_loop: Running optimization trial 153...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:58:09] ax.service.managed_loop: Running optimization trial 154...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:58:15] ax.service.managed_loop: Running optimization trial 155...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:58:22] ax.service.managed_loop: Running optimization trial 156...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:58:28] ax.service.managed_loop: Running optimization trial 157...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:58:34] ax.service.managed_loop: Running optimization trial 158...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:58:40] ax.service.managed_loop: Running optimization trial 159...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:58:47] ax.service.managed_loop: Running optimization trial 160...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:58:54] ax.service.managed_loop: Running optimization trial 161...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:59:03] ax.service.managed_loop: Running optimization trial 162...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:59:10] ax.service.managed_loop: Running optimization trial 163...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:59:16] ax.service.managed_loop: Running optimization trial 164...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:59:21] ax.service.managed_loop: Running optimization trial 165...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:59:28] ax.service.managed_loop: Running optimization trial 166...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:59:32] ax.service.managed_loop: Running optimization trial 167...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:59:39] ax.service.managed_loop: Running optimization trial 168...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:59:42] ax.service.managed_loop: Running optimization trial 169...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:59:48] ax.service.managed_loop: Running optimization trial 170...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 11:59:53] ax.service.managed_loop: Running optimization trial 171...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:00:00] ax.service.managed_loop: Running optimization trial 172...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:00:05] ax.service.managed_loop: Running optimization trial 173...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:00:12] ax.service.managed_loop: Running optimization trial 174...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:00:23] ax.service.managed_loop: Running optimization trial 175...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:00:27] ax.service.managed_loop: Running optimization trial 176...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:00:34] ax.service.managed_loop: Running optimization trial 177...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:00:38] ax.service.managed_loop: Running optimization trial 178...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:00:45] ax.service.managed_loop: Running optimization trial 179...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:00:49] ax.service.managed_loop: Running optimization trial 180...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:00:54] ax.service.managed_loop: Running optimization trial 181...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:01:01] ax.service.managed_loop: Running optimization trial 182...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:01:07] ax.service.managed_loop: Running optimization trial 183...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:01:13] ax.service.managed_loop: Running optimization trial 184...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:01:19] ax.service.managed_loop: Running optimization trial 185...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:01:24] ax.service.managed_loop: Running optimization trial 186...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:01:29] ax.service.managed_loop: Running optimization trial 187...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:01:37] ax.service.managed_loop: Running optimization trial 188...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:01:46] ax.service.managed_loop: Running optimization trial 189...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:01:52] ax.service.managed_loop: Running optimization trial 190...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:02:02] ax.service.managed_loop: Running optimization trial 191...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:02:10] ax.service.managed_loop: Running optimization trial 192...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:02:13] ax.service.managed_loop: Running optimization trial 193...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:02:21] ax.service.managed_loop: Running optimization trial 194...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:02:28] ax.service.managed_loop: Running optimization trial 195...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:02:37] ax.service.managed_loop: Running optimization trial 196...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:02:42] ax.service.managed_loop: Running optimization trial 197...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:02:50] ax.service.managed_loop: Running optimization trial 198...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:02:59] ax.service.managed_loop: Running optimization trial 199...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:03:05] ax.service.managed_loop: Running optimization trial 200...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:03:12] ax.service.managed_loop: Running optimization trial 201...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:03:17] ax.service.managed_loop: Running optimization trial 202...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:03:28] ax.service.managed_loop: Running optimization trial 203...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:03:34] ax.service.managed_loop: Running optimization trial 204...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:03:42] ax.service.managed_loop: Running optimization trial 205...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:03:51] ax.service.managed_loop: Running optimization trial 206...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:04:00] ax.service.managed_loop: Running optimization trial 207...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:04:07] ax.service.managed_loop: Running optimization trial 208...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:04:14] ax.service.managed_loop: Running optimization trial 209...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:04:18] ax.service.managed_loop: Running optimization trial 210...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:04:21] ax.service.managed_loop: Running optimization trial 211...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:04:26] ax.service.managed_loop: Running optimization trial 212...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:04:31] ax.service.managed_loop: Running optimization trial 213...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:04:37] ax.service.managed_loop: Running optimization trial 214...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:04:43] ax.service.managed_loop: Running optimization trial 215...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:04:47] ax.service.managed_loop: Running optimization trial 216...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:04:52] ax.service.managed_loop: Running optimization trial 217...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:04:58] ax.service.managed_loop: Running optimization trial 218...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:05:02] ax.service.managed_loop: Running optimization trial 219...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:05:07] ax.service.managed_loop: Running optimization trial 220...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:05:11] ax.service.managed_loop: Running optimization trial 221...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:05:15] ax.service.managed_loop: Running optimization trial 222...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:05:22] ax.service.managed_loop: Running optimization trial 223...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:05:29] ax.service.managed_loop: Running optimization trial 224...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:05:38] ax.service.managed_loop: Running optimization trial 225...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:05:45] ax.service.managed_loop: Running optimization trial 226...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:05:51] ax.service.managed_loop: Running optimization trial 227...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:05:58] ax.service.managed_loop: Running optimization trial 228...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:06:04] ax.service.managed_loop: Running optimization trial 229...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:06:11] ax.service.managed_loop: Running optimization trial 230...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:06:21] ax.service.managed_loop: Running optimization trial 231...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:06:28] ax.service.managed_loop: Running optimization trial 232...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:06:34] ax.service.managed_loop: Running optimization trial 233...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:06:40] ax.service.managed_loop: Running optimization trial 234...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:06:43] ax.service.managed_loop: Running optimization trial 235...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:06:47] ax.service.managed_loop: Running optimization trial 236...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:06:54] ax.service.managed_loop: Running optimization trial 237...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:06:59] ax.service.managed_loop: Running optimization trial 238...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:07:03] ax.service.managed_loop: Running optimization trial 239...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:07:10] ax.service.managed_loop: Running optimization trial 240...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:07:17] ax.service.managed_loop: Running optimization trial 241...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:07:23] ax.service.managed_loop: Running optimization trial 242...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:07:27] ax.service.managed_loop: Running optimization trial 243...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:07:33] ax.service.managed_loop: Running optimization trial 244...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:07:39] ax.service.managed_loop: Running optimization trial 245...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:07:44] ax.service.managed_loop: Running optimization trial 246...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:07:49] ax.service.managed_loop: Running optimization trial 247...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:07:53] ax.service.managed_loop: Running optimization trial 248...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:07:59] ax.service.managed_loop: Running optimization trial 249...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [INFO 06-23 12:08:04] ax.service.managed_loop: Running optimization trial 250...
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]

# %%
best_params
# Out:
# {'mu_1': -2.030613128786983,
#  'sigma_1': 0.38339599562393845,
#  'mu_2': -0.3112777302518155,
#  'sigma_2': 0.36333705487300416,
#  'mu_3': -1.7962927237363142,
#  'sigma_3': 0.7411259119031898,
#  'mu_4': -1.1358485463473564,
#  'sigma_4': 3.0,
#  'mu_5': -1.8801717503539237,
#  'sigma_5': 1e-05,
#  'mu_6': 0.8471182247533822,
#  'sigma_6': 0.24065157797133155,
#  'alpha': 5.1182356846764065}

# %%
BO.get_model_probs(best_params, partitions)
# Out:
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# [array([0.70133333, 0.29866667]),
#  array([0.81733333, 0.18266667]),
#  array([0.59066667, 0.40933333]),
#  array([0.84733333, 0.15266667]),
#  array([0.73466667, 0.26533333]),
#  array([0.63333333, 0.36666667])]

# %%
expert_probs
# Out:
# [array([0.8854, 0.1146]),
#  array([0.7857, 0.2143]),
#  array([0.2237, 0.7763]),
#  array([0.9023, 0.0977]),
#  array([0.8167, 0.1833]),
#  array([0.7857, 0.2143])]

# %%
BO.eval_function(best_params, partitions, expert_probs)
# Out:
# Sampling: [Y_obs, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6]
# Array(5.5718493, dtype=float32)
